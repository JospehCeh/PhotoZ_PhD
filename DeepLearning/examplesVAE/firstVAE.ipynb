# %% [markdown]
# # Variational Autoencoders
#
# Variational autoencoders view autoencoding from a statistical perspective. Like classical autoencoders, they encode a dataset into a lower dimensional latent space. Additionally, though, variational autoencoders constrain the encoded vectors to roughly follow a probability distribution, e.g. a normal distribution. Here’s an example of a variational autoencoder for the same 1D sequence to sequence monochromatic signal encoding problem.

# %% [markdown]
# https://mlgeophysics.github.io/community/projects/auto-encoder/vae/

# %% [markdown]
# ## Variational Autoencoder¶
#
# Much of this code is from https://blog.keras.io/building-autoencoders-in-keras.html and https://github.com/keras-team/keras/blob/master/examples/variational_autoencoder.py
#
# Tutorials can be found at https://towardsdatascience.com/intuitively-understanding-variational-autoencoders-1bfe67eb5daf, https://jaan.io/what-is-variational-autoencoder-vae-tutorial/, and https://arxiv.org/abs/1606.05908
#
# This notebook uses the same toy problem as the autoencoding notebook. Here we demonstrate the use of a variational autoencoder.

# %%
import numpy as np 
import matplotlib.pyplot as plt
import scipy.stats

import tensorflow as tf

#from keras.models import Input 
from keras.models import Model
from keras.models import load_model

from keras.layers import Dense, LeakyReLU, Lambda, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import plot_model
from keras.losses import mse
from keras import backend as K

from sklearn.model_selection import train_test_split

# Init Fidle environment
import fidle
# Out:
# 2023-03-21 15:45:06.886450: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
import tensorflow._api.v2.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /Users/dagoret/opt/anaconda3/envs/fidle23/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
tf.config.run_functions_eagerly(False)

# %%
run_id, run_dir, datasets_dir = fidle.init('MNIST1')
# Out:
# <style>
#
# div.warn {
#     background-color: #fcf2f2;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
#     font-weight: bold;
#     font-size: 1.1em;;
#     }
#
#
#
# div.nota {
#     background-color: #DAFFDE;
#     border-left: 5px solid #92CC99;
#     padding: 0.5em;
#     }
#
# div.todo:before { content:url(data:image/svg+xml;base64,...);
#     float:left;
#     margin-right:20px;
#     margin-top:-20px;
#     margin-bottom:20px;
# }
# div.todo{
#     font-weight: bold;
#     font-size: 1.1em;
#     margin-top:40px;
# }
# div.todo ul{
#     margin: 0.2em;
# }
# div.todo li{
#     margin-left:60px;
#     margin-top:0;
#     margin-bottom:0;
# }
#
# div .comment{
#     font-size:0.8em;
#     color:#696969;
# }
#
#
#
# </style>
# <br>**FIDLE - Environment initialization**
# Version              : 2.0b56
# Run id               : MNIST1
# Run dir              : ./run/MNIST1
# Datasets dir         : /Volumes/Backup2020/MacOSX/GitHub/Fidle2023/fidle-tp/datasets-fidle
# Start time           : 21/03/23 15:45:15
# Hostname             : iMac-de-Sylvie.local (Darwin)
# Tensorflow log level : Info + Warning + Error  (=0)
# Update keras cache   : False
# Save figs            : ./run/MNIST1/figs (False)
# tensorflow           : 2.11.1
# numpy                : 1.23.5
# sklearn              : 1.2.2
# matplotlib           : 3.7.1
# pandas               : 1.5.3

# %% [markdown]
# ## generate training, test, and validation data

# %%
# generate training, test, and validation data
n = 4096
nt = 128
f = 3.0                  # frequency in Hz
t = np.linspace(0,1,nt)  # time stamps in s
x = np.zeros((n,nt),dtype=np.float32)
phase = np.random.uniform(-np.pi, np.pi, size=n)
for i in range(n):
    x[i,:] = np.sin(2*np.pi*f*t + phase[i] )

# %%
# QC generated data is phase shifted but one frequency
plt.figure(figsize=(8,2))
for i in range(3):
    plt.plot(t,x[np.random.randint(0,nt-1), :])
plt.show()

# %%
# QC generated phase in [-pi,pi]
plt.figure(figsize=(8,2))
plt.hist(phase,bins=31)
plt.xlabel('phase')
plt.ylabel('number of occurence')
plt.show()

# %%
# split into test, validation, and training sets
x_temp, x_test, _, _ = train_test_split(x, x, test_size=0.05)
x_train, x_valid, _, _ = train_test_split(x_temp,
                                          x_temp,
                                          test_size=0.1)
n_train = len(x_train)
n_valid = len(x_valid)
n_test = len(x_test)

# %%
# specify training parameters and callback functions

# batch size for stochastic solver  
batch_size = 16

# number of times entire dataset is considered in stochastic solver
epochs = 100

# unique name for the network for saving
unique_name = "testvae"
model_filename = 'aen_sin_%03dHz_n=%05d_'%(int(f),nt)+unique_name+'.h5'

# training history file name
history_filename = 'results_'+unique_name+'.npz'

# stop early after no improvement past epochs=patience and be verbose
earlystopper = EarlyStopping(patience=100, verbose=1)

# checkpoint and save model when improvement occurs 
checkpointer = ModelCheckpoint(model_filename, verbose=1, save_best_only=True)

# consolidate callback functions for convenience 
callbacks = [earlystopper, checkpointer]

# %% [markdown]
# Now things get a bit different from a vanilla autoencoder. First, we set the dimensions of the latent space. For this example we can get away with only one dimension. Intuitively, since the only difference between training examples is the phase, we only need one to encode one dimension.

# %%
# encoding dimension; i.e. dimensionality of the latent space
encoding_dim=1

# %% [markdown]
# Next we define a function to draw samples from a Gaussian, given the mean and standard deviation. We sample to encode in the latent space. Further, the way this function is defined, it lets us use backpropagation on the mean and standard deviation, even though there's a probabilistic element to this operation (this is the "reparameterization trick").

# %%
# define a function to sample from gaussian, given mean and log variance
def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(encoding_dim,))
    return z_mean + K.exp(z_log_sigma) * epsilon

# %% [markdown]
# Network structure is similar to the autoencoder. The main difference is in the middle of the network: z_mean and z_log_sigma. These layers encode a mean and log(std) that determine the pdf that we draw the encoding in the latent space from.
#
#
#
# The "Lambda" layer then draws a sample from that pdf, and z is the encoded signal in the latent space.

# %% [markdown]
# ## input layer is full time series of length nt

# %%
# input layer is full time series of length nt
inputs = Input((nt,))

# %% [markdown]
# ## encoder hidden layers

# %%
# encoder hidden layers
encoded = Dense(64)(inputs) 
encoded = LeakyReLU(alpha=0.2)(encoded)
encoded = Dense(32)(encoded)
encoded = LeakyReLU(alpha=0.2)(encoded)
z_mean = Dense(encoding_dim)(encoded)
z_log_sigma = Dense(encoding_dim)(encoded)
z = Lambda(sampling,output_shape=(encoding_dim,))([z_mean,z_log_sigma])

# %% [markdown]
# ## decoder hidden layers

# %%
decoded = Dense(32)(z)
decoded = LeakyReLU(alpha=0.2)(decoded)
decoded = Dense(64)(decoded)
decoded = LeakyReLU(alpha=0.2)(decoded)
# output layer is same length as input
outputs = Dense(nt,activation='tanh')(decoded)

# %% [markdown]
# ## consolidate to define autoencoder model inputs and outputs

# %%
# consolidate to define autoencoder model inputs and outputs
vae = Model(inputs=inputs, outputs=outputs)

# %%
# specify encoder and decoder model for easy encoding and decoding later
encoder = Model(inputs=inputs, outputs=[z_mean,z_log_sigma,z],name='encoder')
# create a placeholder for an encoded input
encoded_input = Input(shape=(encoding_dim,))

# %%
# retrieve the last layers of the autoencoder model
decoded_output = vae.layers[-5](encoded_input)
decoded_output = vae.layers[-4](decoded_output)
decoded_output = vae.layers[-3](decoded_output)
decoded_output = vae.layers[-2](decoded_output)
decoded_output = vae.layers[-1](decoded_output)
# create the decoder model
decoder = Model(inputs=encoded_input, outputs=decoded_output, name='decoder')

# %%
print('Full autoencoder')
print(vae.summary())
# Out:
# Full autoencoder
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128)]        0           []
#
#  dense (Dense)                  (None, 64)           8256        ['input_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 64)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 32)           2080        ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 32)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            33          ['leaky_re_lu_1[0][0]']
#
#  dense_3 (Dense)                (None, 1)            33          ['leaky_re_lu_1[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['dense_2[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           64          ['lambda[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 32)           0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 64)           2112        ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 64)           0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 128)          8320        ['leaky_re_lu_3[0][0]']
#
# ==================================================================================================
# Total params: 20,898
# Trainable params: 20,898
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## VAE loss

# %% [markdown]
# The loss function is another key difference between standard autoencoders and variational autoencoders. A standard autoencoder simply minimizes reconstruction loss.
#
# - A variational autoencoder minimizes both reconstruction loss and the KL divergence.
#
# - The KL divergence is a measure of how much two probability distributions differ.
#
#
# Minimizing the KL divergence here means that we are encouraging the latent space encodings to have a normal distribution. The regularization parameter balances between reconstruction loss and enforcing a normal distribution in the latent space.

# %%
# specify loss
# regularization balances signal reconstruction with
# a Gaussian distribution in the latent space 
regularization = 10
def vae_loss(input_img, output):
    # compute the average MSE error, then scale it up, ie. simply sum on all axes
    reconstruction_loss = K.sum(K.square(output-input_img))
    kl_loss = - 0.5 * K.sum(1 + z_log_sigma - K.square(z_mean) - K.square(K.exp(z_log_sigma)), axis=-1)
    # return the average loss over all images in batch
    total_loss = K.mean(reconstruction_loss + regularization*kl_loss)    
    return total_loss

vae.compile(optimizer='adam', loss=vae_loss, metrics=['mse'],experimental_run_tf_function=False,run_eagerly=False)
vae.run_eagerly = False

# %% [markdown]
# ## train variational autoencoder

# %%
# train variational autoencoder
results = vae.fit(x_train,x_train,
                      shuffle=True,
                      batch_size = batch_size, 
                      epochs = epochs,
                      validation_data = (x_valid,x_valid),
                      callbacks = callbacks)
# Out:
# Train on 3501 samples, validate on 390 samples
# Epoch 1/100
# 2023-03-21 15:45:16.986924: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-21 15:45:17.010493: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2023-03-21 15:45:17.048008: W tensorflow/c/c_api.cc:291] Operation '{name:'training/Adam/dense_5/kernel/v/Assign' id:573 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_5/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_5/kernel/v, training/Adam/dense_5/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2832/3501 [=======================>......] - ETA: 0s - loss: 627.4551 - mean_squared_error: 0.2955
# Epoch 1: val_loss improved from inf to 540.48994, saving model to aen_sin_003Hz_n=00128_testvae.h5
# /Users/dagoret/opt/anaconda3/envs/fidle23/lib/python3.9/site-packages/keras/engine/training_v1.py:2333: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-03-21 15:45:17.413088: W tensorflow/c/c_api.cc:291] Operation '{name:'loss/mul' id:235 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/dense_6_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 3501/3501 [==============================] - 1s 167us/sample - loss: 610.7825 - mean_squared_error: 0.2881 - val_loss: 540.4899 - val_mean_squared_error: 0.2595
# Epoch 2/100
# 2672/3501 [=====================>........] - ETA: 0s - loss: 529.3166 - mean_squared_error: 0.2516
# Epoch 2: val_loss improved from 540.48994 to 531.53066, saving model to aen_sin_003Hz_n=00128_testvae.h5
# 3501/3501 [==============================] - 0s 70us/sample - loss: 533.1814 - mean_squared_error: 0.2539 - val_loss: 531.5307 - val_mean_squared_error: 0.2564
# Epoch 3/100
# 2768/3501 [======================>.......] - ETA: 0s - loss: 519.7502 - mean_squared_error: 0.2477
# Epoch 3: val_loss improved from 531.53066 to 410.96187, saving model to aen_sin_003Hz_n=00128_testvae.h5
# 3501/3501 [==============================] - 0s 68us/sample - loss: 508.7815 - mean_squared_error: 0.2423 - val_loss: 410.9619 - val_mean_squared_error: 0.1951
# Epoch 4/100
# 2640/3501 [=====================>........] - ETA: 0s - loss: 258.7287 - mean_squared_error: 0.1154
# Epoch 4: val_loss improved from 410.96187 to 171.37293, saving model to aen_sin_003Hz_n=00128_testvae.h5
# 3501/3501 [==============================] - 0s 71us/sample - loss: 235.2830 - mean_squared_error: 0.1041 - val_loss: 171.3729 - val_mean_squared_error: 0.0725
# Epoch 5/100
# 2752/3501 [======================>.......] - ETA: 0s - loss: 159.7233 - mean_squared_error: 0.0689
# Epoch 5: val_loss improved from 171.37293 to 113.24193, saving model to aen_sin_003Hz_n=00128_testvae.h5
# 3501/3501 [==============================] - 0s 68us/sample - loss: 150.9426 - mean_squared_error: 0.0647 - val_loss: 113.2419 - val_mean_squared_error: 0.0476
# Epoch 6/100
# 3376/3501 [===========================>..] - ETA: 0s - loss: 118.2822 - mean_squared_error: 0.0483
# Epoch 6: val_loss did not improve from 113.24193
# 3501/3501 [==============================] - 0s 66us/sample - loss: 118.8072 - mean_squared_error: 0.0486 - val_loss: 161.1759 - val_mean_squared_error: 0.0690
# Epoch 7/100
# 2816/3501 [=======================>......] - ETA: 0s - loss: 130.5802 - mean_squared_error: 0.0526
# Epoch 7: val_loss did not improve from 113.24193
# 3501/3501 [==============================] - 0s 58us/sample - loss: 128.9007 - mean_squared_error: 0.0524 - val_loss: 113.8368 - val_mean_squared_error: 0.0473
# Epoch 8/100
# 3232/3501 [==========================>...] - ETA: 0s - loss: 116.6843 - mean_squared_error: 0.0483
# Epoch 8: val_loss improved from 113.24193 to 102.52420, saving model to aen_sin_003Hz_n=00128_testvae.h5
# 3501/3501 [==============================] - 0s 76us/sample - loss: 114.4914 - mean_squared_error: 0.0472 - val_loss: 102.5242 - val_mean_squared_error: 0.0411
# Epoch 9/100
# 3408/3501 [============================>.] - ETA: 0s - loss: 97.7834 - mean_squared_error: 0.0390
# Epoch 9: val_loss improved from 102.52420 to 87.42067, saving model to aen_sin_003Hz_n=00128_testvae.h5
# 3501/3501 [==============================] - 0s 74us/sample - loss: 96.9437 - mean_squared_error: 0.0386 - val_loss: 87.4207 - val_mean_squared_error: 0.0340
# Epoch 10/100
# 3392/3501 [============================>.] - ETA: 0s - loss: 84.5450 - mean_squared_error: 0.0326
# Epoch 10: val_loss did not improve from 87.42067
# 3501/3501 [==============================] - 0s 64us/sample - loss: 83.8129 - mean_squared_error: 0.0323 - val_loss: 97.2271 - val_mean_squared_error: 0.0396
# Epoch 11/100
# 2752/3501 [======================>.......] - ETA: 0s - loss: 86.5267 - mean_squared_error: 0.0339
# Epoch 11: val_loss did not improve from 87.42067
# 3501/3501 [==============================] - 0s 61us/sample - loss: 84.8822 - mean_squared_error: 0.0331 - val_loss: 121.1149 - val_mean_squared_error: 0.0518
# Epoch 12/100
# 2736/3501 [======================>.......] - ETA: 0s - loss: 85.9254 - mean_squared_error: 0.0332
# Epoch 12: val_loss improved from 87.42067 to 51.73445, saving model to aen_sin_003Hz_n=00128_testvae.h5
# 3501/3501 [==============================] - 0s 69us/sample - loss: 85.8753 - mean_squared_error: 0.0332 - val_loss: 51.7344 - val_mean_squared_error: 0.0168
# Epoch 13/100
# 2736/3501 [======================>.......] - ETA: 0s - loss: 72.2597 - mean_squared_error: 0.0269
# Epoch 13: val_loss did not improve from 51.73445
# 3501/3501 [==============================] - 0s 59us/sample - loss: 72.3099 - mean_squared_error: 0.0270 - val_loss: 84.6541 - val_mean_squared_error: 0.0333
# Epoch 14/100
# 2800/3501 [======================>.......] - ETA: 0s - loss: 78.0836 - mean_squared_error: 0.0300
# Epoch 14: val_loss did not improve from 51.73445
# 3501/3501 [==============================] - 0s
val_loss did not improve from 27.96161
# 3501/3501 [==============================] - 0s 74us/sample - loss: 50.9671 - mean_squared_error: 0.0147 - val_loss: 32.6001 - val_mean_squared_error: 0.0073
# Epoch 98/100
# 3296/3501 [===========================>..] - ETA: 0s - loss: 48.9046 - mean_squared_error: 0.0151
# Epoch 98: val_loss did not improve from 27.96161
# 3501/3501 [==============================] - 0s 67us/sample - loss: 48.0821 - mean_squared_error: 0.0147 - val_loss: 59.1309 - val_mean_squared_error: 0.0207
# Epoch 99/100
# 3501/3501 [==============================] - ETA: 0s - loss: 42.8712 - mean_squared_error: 0.0124
# Epoch 99: val_loss did not improve from 27.96161
# 3501/3501 [==============================] - 0s 63us/sample - loss: 42.8712 - mean_squared_error: 0.0124 - val_loss: 58.5934 - val_mean_squared_error: 0.0227
# Epoch 100/100
# 3072/3501 [=========================>....] - ETA: 0s - loss: 51.6963 - mean_squared_error: 0.0161
# Epoch 100: val_loss did not improve from 27.96161
# 3501/3501 [==============================] - 0s 70us/sample - loss: 50.7628 - mean_squared_error: 0.0158 - val_loss: 47.7995 - val_mean_squared_error: 0.0146

# %%
# QC training and validation curves (should follow eachother)
plt.figure(figsize=(8,2))
plt.plot(results.history['val_loss'], label='val')
plt.plot(results.history['loss'], label='train')
plt.xlabel('epoch index')
plt.ylabel('loss value (MSE)')
plt.legend()
plt.show()

# %% [markdown]
# ## First, let's check to see how well the encoder is working.

# %%
encoded_test = np.array(encoder.predict(x_test))
vae_test = vae.predict(x_test)
# Out:
# /Users/dagoret/opt/anaconda3/envs/fidle23/lib/python3.9/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-03-21 15:45:40.544724: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/BiasAdd' id:64 op device:{requested: '', assigned: ''} def:{{{node dense_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_2/MatMul, dense_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-21 15:45:40.627308: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_6/Tanh' id:156 op device:{requested: '', assigned: ''} def:{{{node dense_6/Tanh}} = Tanh[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_6/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
plt.plot(x_test[0],label='true signal')
plt.plot(vae_test[0],label='encoded-decoded signal')
plt.legend()
plt.show()

# %% [markdown]
# ## Now let's look at the distribution of samples in the latent space, to see how gaussian it is.

# %%
import matplotlib.mlab as mlab
n,bins,patches=plt.hist(encoded_test[2,:,:].flatten(),bins=10,density=True)
plt.plot(bins,scipy.stats.norm.pdf(bins,0,1))
plt.show()

# %% [markdown]
# ## Now let's see how the decoded signal depends on the latent vector.

# %%
from matplotlib.pylab import cm
plt.figure(figsize=(10,4))
latent_inputs = np.repeat(np.linspace(-3,3,11)[:,np.newaxis],encoding_dim,axis=1)
decoded_latent_inputs = decoder.predict(latent_inputs)
colors = cm.viridis(np.linspace(0,1,len(latent_inputs)))
for i,latent_input in enumerate(decoded_latent_inputs):
    plt.plot(t,latent_input,color=colors[i])
labels = ["{0:.1f}".format(l) for l in latent_inputs[:,0]]
plt.legend(labels)
plt.show()
# Out:
# 2023-03-21 15:45:40.998179: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_6_1/Tanh' id:172 op device:{requested: '', assigned: ''} def:{{{node dense_6_1/Tanh}} = Tanh[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_6_1/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %% [markdown]
# Interestingly, the autoencoder has learned to use the latent vector (value in this case, since we specified an encoding dimension of 1) as a proxy for phase. As the latent value changes, the phase of the decoded signal changes. Latent values near zero reproduce a sine wave well, while values far from zero produce signals that aren't exactly sinusoidal.
